# %% [markdown]
# # Exploring the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
data = pd.read_csv("data_neutral.csv", sep = ";")

# %%
data.head()
# Out:
#    Unnamed: 0          Onderwijssoort Studierichting  Perioden  Enrollment  \
# 0        1884  Hoger beroepsonderwijs         Totaal      2010      416638
# 1        1885  Hoger beroepsonderwijs         Totaal      2011      423945
# 2        1886  Hoger beroepsonderwijs         Totaal      2012      421693
# 3        1887  Hoger beroepsonderwijs         Totaal      2013      440293
# 4        1888  Hoger beroepsonderwijs         Totaal      2014      446434
#
#    Freshmen
# 0    100104
# 1     99019
# 2     97006
# 3    102817
# 4     98505

# %%
data.tail
# Out:
# <bound method NDFrame.tail of       Unnamed: 0              Onderwijssoort              Studierichting  \
# 0           1884      Hoger beroepsonderwijs                      Totaal
# 1           1885      Hoger beroepsonderwijs                      Totaal
# 2           1886      Hoger beroepsonderwijs                      Totaal
# 3           1887      Hoger beroepsonderwijs                      Totaal
# 4           1888      Hoger beroepsonderwijs                      Totaal
# ...          ...                         ...                         ...
# 3763        5647  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3764        5648  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3765        5649  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3766        5650  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3767        5651  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
#
#       Perioden  Enrollment  Freshmen
# 0         2010      416638    100104
# 1         2011      423945     99019
# 2         2012      421693     97006
# 3         2013      440293    102817
# 4         2014      446434     98505
# ...        ...         ...       ...
# 3763      2017         476        86
# 3764      2018         445        77
# 3765      2019         416        76
# 3766      2020         406       103
# 3767      2021         412        77
#
# [3768 rows x 6 columns]>

# %% [markdown]
# ### Into SQL

# %%
import pymysql
from sqlalchemy import create_engine
import getpass

# %%
passwd = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+passwd+'@localhost/enrollment'
engine = create_engine(connection_string)

# %%
data.to_sql('enrollment', engine, if_exists='replace', index = False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 data.to_sql('enrollment', engine, if_exists='replace', index = False)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:1732, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1682 """
#    1683 Write records stored in a DataFrame to a SQL database.
#    1684
#    (...)
#    1728     Any additional kwargs are passed to the engine.
#    1729 """
#    1730 sql_engine = get_engine(engine)
# -> 1732 table = self.prep_table(
#    1733     frame=frame,
#    1734     name=name,
#    1735     if_exists=if_exists,
#    1736     index=index,
#    1737     index_label=index_label,
#    1738     schema=schema,
#    1739     dtype=dtype,
#    1740 )
#    1742 total_inserted = sql_engine.insert_records(
#    1743     table=table,
#    1744     con=self.connectable,
#    (...)
#    1751     **engine_kwargs,
#    1752 )
#    1754 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:832, in SQLTable.create(self)
#     831 def create(self):
# --> 832     if self.exists():
#     833         if self.if_exists == "fail":
#     834             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:816, in SQLTable.exists(self)
#     815 def exists(self):
# --> 816     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:1765, in SQLDatabase.has_table(self, name, schema)
#    1762 if _gt14():
#    1763     from sqlalchemy import inspect
# -> 1765     insp = inspect(self.connectable)
#    1766     return insp.has_table(name, schema or self.meta.schema)
#    1767 else:
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/inspection.py:64, in inspect(subject, raiseerr)
#      62 if reg is True:
#      63     return subject
# ---> 64 ret = reg(subject)
#      65 if ret is not None:
#      66     break
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/reflection.py:182, in Inspector._engine_insp(bind)
#     180 @inspection._inspects(Engine)
#     181 def _engine_insp(bind):
# --> 182     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/reflection.py:117, in Inspector._construct(cls, init, bind)
#     114     cls = bind.dialect.inspector
#     116 self = cls.__new__(cls)
# --> 117 init(self, bind)
#     118 return self
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/reflection.py:128, in Inspector._init_engine(self, engine)
#     126 def _init_engine(self, engine):
#     127     self.bind = self.engine = engine
# --> 128     engine.connect().close()
#     129     self._op_context_requires_connect = True
#     130     self.dialect = self.engine.dialect
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:3315, in Engine.connect(self, close_with_result)
#    3300 def connect(self, close_with_result=False):
#    3301     """Return a new :class:`_engine.Connection` object.
#    3302
#    3303     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3312
#    3313     """
# -> 3315     return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:3394, in Engine.raw_connection(self, _connection)
#    3372 def raw_connection(self, _connection=None):
#    3373     """Return a "raw" DBAPI connection from the connection pool.
#    3374
#    3375     The returned object is a proxied version of the DBAPI
#    (...)
#    3392
#    3393     """
# -> 3394     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3359 dialect = self.dialect
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#    3363     if connection is None:
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:320, in Pool.connect(self)
#     312 def connect(self):
#     313     """Return a DBAPI connection from the pool.
#     314
#     315     The connection is instrumented such that when its
#    (...)
#     318
#     319     """
# --> 320     return _ConnectionFairy._checkout(self)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:884, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     881 @classmethod
#     882 def _checkout(cls, pool, threadconns=None, fairy=None):
#     883     if not fairy:
# --> 884         fairy = _ConnectionRecord.checkout(pool)
#     886         fairy._pool = pool
#     887         fairy._counter = 0
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:486, in _ConnectionRecord.checkout(cls, pool)
#     484 @classmethod
#     485 def checkout(cls, pool):
# --> 486     rec = pool._do_get()
#     487     try:
#     488         dbapi_connection = rec.get_connection()
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     143         return self._create_connection()
#     144     except:
# --> 145         with util.safe_reraise():
#     146             self._dec_overflow()
#     147 else:
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:266, in Pool._create_connection(self)
#     263 def _create_connection(self):
#     264     """Called by subclasses to create a new ConnectionRecord."""
# --> 266     return _ConnectionRecord(self)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:381, in _ConnectionRecord.__init__(self, pool, connect)
#     379 self.__pool = pool
#     380 if connect:
# --> 381     self.__connect()
#     382 self.finalize_callback = deque()
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:677, in _ConnectionRecord.__connect(self)
#     675     self.fresh = True
#     676 except Exception as e:
# --> 677     with util.safe_reraise():
#     678         pool.logger.debug("Error on connect(): %s", e)
#     679 else:
#     680     # in SQLAlchemy 1.4 the first_connect event is not used by
#     681     # the engine, so this will usually not be set
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:673, in _ConnectionRecord.__connect(self)
#     671 try:
#     672     self.starttime = time.time()
# --> 673     self.dbapi_connection = connection = pool._invoke_creator(self)
#     674     pool.logger.debug("Created new connection %r", connection)
#     675     self.fresh = True
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/create.py:578, in create_engine.<locals>.connect(connection_record)
#     576         if connection is not None:
#     577             return connection
# --> 578 return dialect.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351     self._sock = None
#     352 else:
# --> 353     self.connect()
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/connections.py:633, in Connection.connect(self, sock)
#     630 self._next_seq_id = 0
#     632 self._get_server_information()
# --> 633 self._request_authentication()
#     635 if self.sql_mode is not None:
#     636     c = self.cursor()
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/connections.py:932, in Connection._request_authentication(self)
#     930 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     931 if self._auth_plugin_name == "caching_sha2_password":
# --> 932     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     933 elif self._auth_plugin_name == "sha256_password":
#     934     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/_auth.py:265, in caching_sha2_password_auth(conn, pkt)
#     262     if DEBUG:
#     263         print(conn.server_public_key.decode("ascii"))
# --> 265 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
#     266 pkt = _roundtrip(conn, data)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/_auth.py:143, in sha2_rsa_encrypt(password, salt, public_key)
#     138 """Encrypt password with salt and public_key.
#     139
#     140 Used for sha256_password and caching_sha2_password.
#     141 """
#     142 if not _have_cryptography:
# --> 143     raise RuntimeError(
#     144         "'cryptography' package is required for sha256_password or caching_sha2_password auth methods"
#     145     )
#     146 message = _xor_password(password + b"\0", salt)
#     147 rsa_key = serialization.load_pem_public_key(public_key, default_backend())
#
# RuntimeError: 'cryptography' package is required for sha256_password or caching_sha2_password auth methods

# %% [markdown]
# ### And back from SQL (this is totally identical to what I put in there, I only learned about the requirement to load from SQL back to python after I'd already done the exploring in SQL and the cleaning in python. But here you go - just to check the box)

# %%
sqldata = pd.read_sql_query('SELECT * FROM enrollment', engine)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 sqldata = pd.read_sql_query('SELECT * FROM enrollment', engine)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:400, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     342 """
#     343 Read SQL query into a DataFrame.
#     344
#    (...)
#     397 parameter will be converted to UTC.
#     398 """
#     399 pandas_sql = pandasSQL_builder(con)
# --> 400 return pandas_sql.read_query(
#     401     sql,
#     402     index_col=index_col,
#     403     params=params,
#     404     coerce_float=coerce_float,
#     405     parse_dates=parse_dates,
#     406     chunksize=chunksize,
#     407     dtype=dtype,
#     408 )
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:1560, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1512 """
#    1513 Read SQL query into a DataFrame.
#    1514
#    (...)
#    1556
#    1557 """
#    1558 args = _convert_params(sql, params)
# -> 1560 result = self.execute(*args)
#    1561 columns = result.keys()
#    1563 if chunksize is not None:
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/io/sql.py:1405, in SQLDatabase.execute(self, *args, **kwargs)
#    1403 def execute(self, *args, **kwargs):
#    1404     """Simple passthrough to SQLAlchemy connectable"""
# -> 1405     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:3256, in Engine.execute(self, statement, *multiparams, **params)
#    3230 @util.deprecated_20(
#    3231     ":meth:`_engine.Engine.execute`",
#    3232     alternative="All statement execution in SQLAlchemy 2.0 is performed "
#    (...)
#    3237 )
#    3238 def execute(self, statement, *multiparams, **params):
#    3239     """Executes the given construct and returns a
#    3240     :class:`_engine.CursorResult`.
#    3241
#    (...)
#    3254
#    3255     """
# -> 3256     connection = self.connect(close_with_result=True)
#    3257     return connection.execute(statement, *multiparams, **params)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:3315, in Engine.connect(self, close_with_result)
#    3300 def connect(self, close_with_result=False):
#    3301     """Return a new :class:`_engine.Connection` object.
#    3302
#    3303     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3312
#    3313     """
# -> 3315     return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:3394, in Engine.raw_connection(self, _connection)
#    3372 def raw_connection(self, _connection=None):
#    3373     """Return a "raw" DBAPI connection from the connection pool.
#    3374
#    3375     The returned object is a proxied version of the DBAPI
#    (...)
#    3392
#    3393     """
# -> 3394     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3359 dialect = self.dialect
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#    3363     if connection is None:
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:320, in Pool.connect(self)
#     312 def connect(self):
#     313     """Return a DBAPI connection from the pool.
#     314
#     315     The connection is instrumented such that when its
#    (...)
#     318
#     319     """
# --> 320     return _ConnectionFairy._checkout(self)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:884, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     881 @classmethod
#     882 def _checkout(cls, pool, threadconns=None, fairy=None):
#     883     if not fairy:
# --> 884         fairy = _ConnectionRecord.checkout(pool)
#     886         fairy._pool = pool
#     887         fairy._counter = 0
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:486, in _ConnectionRecord.checkout(cls, pool)
#     484 @classmethod
#     485 def checkout(cls, pool):
# --> 486     rec = pool._do_get()
#     487     try:
#     488         dbapi_connection = rec.get_connection()
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     143         return self._create_connection()
#     144     except:
# --> 145         with util.safe_reraise():
#     146             self._dec_overflow()
#     147 else:
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:266, in Pool._create_connection(self)
#     263 def _create_connection(self):
#     264     """Called by subclasses to create a new ConnectionRecord."""
# --> 266     return _ConnectionRecord(self)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:381, in _ConnectionRecord.__init__(self, pool, connect)
#     379 self.__pool = pool
#     380 if connect:
# --> 381     self.__connect()
#     382 self.finalize_callback = deque()
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:677, in _ConnectionRecord.__connect(self)
#     675     self.fresh = True
#     676 except Exception as e:
# --> 677     with util.safe_reraise():
#     678         pool.logger.debug("Error on connect(): %s", e)
#     679 else:
#     680     # in SQLAlchemy 1.4 the first_connect event is not used by
#     681     # the engine, so this will usually not be set
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/pool/base.py:673, in _ConnectionRecord.__connect(self)
#     671 try:
#     672     self.starttime = time.time()
# --> 673     self.dbapi_connection = connection = pool._invoke_creator(self)
#     674     pool.logger.debug("Created new connection %r", connection)
#     675     self.fresh = True
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/create.py:578, in create_engine.<locals>.connect(connection_record)
#     576         if connection is not None:
#     577             return connection
# --> 578 return dialect.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.10/lib/python/site-packages/sqlalchemy/engine/default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351     self._sock = None
#     352 else:
# --> 353     self.connect()
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/connections.py:633, in Connection.connect(self, sock)
#     630 self._next_seq_id = 0
#     632 self._get_server_information()
# --> 633 self._request_authentication()
#     635 if self.sql_mode is not None:
#     636     c = self.cursor()
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/connections.py:932, in Connection._request_authentication(self)
#     930 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     931 if self._auth_plugin_name == "caching_sha2_password":
# --> 932     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     933 elif self._auth_plugin_name == "sha256_password":
#     934     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/_auth.py:265, in caching_sha2_password_auth(conn, pkt)
#     262     if DEBUG:
#     263         print(conn.server_public_key.decode("ascii"))
# --> 265 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
#     266 pkt = _roundtrip(conn, data)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pymysql/_auth.py:143, in sha2_rsa_encrypt(password, salt, public_key)
#     138 """Encrypt password with salt and public_key.
#     139
#     140 Used for sha256_password and caching_sha2_password.
#     141 """
#     142 if not _have_cryptography:
# --> 143     raise RuntimeError(
#     144         "'cryptography' package is required for sha256_password or caching_sha2_password auth methods"
#     145     )
#     146 message = _xor_password(password + b"\0", salt)
#     147 rsa_key = serialization.load_pem_public_key(public_key, default_backend())
#
# RuntimeError: 'cryptography' package is required for sha256_password or caching_sha2_password auth methods

# %% [markdown]
# This worked before - I SWEAR - but we're at the end of a long week so I'm not about to fight python over some cryptography nonsense.

# %% [markdown]
# ### I will start by extracting the data for the 'outer layer' of 'studierichting' - with codes 01 - 10.

# %%
level1 = data[data['Studierichting'].str.contains('^[0-9][0-9] ', regex=True)]

# %%
level1
# Out:
#       Unnamed: 0              Onderwijssoort      Studierichting  Perioden  \
# 12          1896      Hoger beroepsonderwijs        01 Onderwijs      2010
# 13          1897      Hoger beroepsonderwijs        01 Onderwijs      2011
# 14          1898      Hoger beroepsonderwijs        01 Onderwijs      2012
# 15          1899      Hoger beroepsonderwijs        01 Onderwijs      2013
# 16          1900      Hoger beroepsonderwijs        01 Onderwijs      2014
# ...          ...                         ...                 ...       ...
# 3523        5407  Wetenschappelijk onderwijs  10 Dienstverlening      2017
# 3524        5408  Wetenschappelijk onderwijs  10 Dienstverlening      2018
# 3525        5409  Wetenschappelijk onderwijs  10 Dienstverlening      2019
# 3526        5410  Wetenschappelijk onderwijs  10 Dienstverlening      2020
# 3527        5411  Wetenschappelijk onderwijs  10 Dienstverlening      2021
#
#       Enrollment  Freshmen
# 12         77857     15372
# 13         75008     14107
# 14         70683     13108
# 15         72145     13724
# 16         72412     13490
# ...          ...       ...
# 3523        1394       286
# 3524        1585       348
# 3525        1767       423
# 3526        2260       536
# 3527        2511       496
#
# [240 rows x 6 columns]

# %% [markdown]
# This also drops 'studierichting onbekend' - I'll have to check if those values stay roughly the same over the years (in proportion to total enrollment). If so, I can ignore them for the rest of the project. If not, I'll have to think about what to do with them.

# %% [markdown]
# # Here comes a little detour

# %%
onbekend = data[data['Studierichting'].str.contains('onbekend', regex=True)]

# %%
onbekend
# Out:
#       Unnamed: 0              Onderwijssoort              Studierichting  \
# 1872        3756      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1873        3757      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1874        3758      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1875        3759      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1876        3760      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1877        3761      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1878        3762      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1879        3763      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1880        3764      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1881        3765      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1882        3766      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 1883        3767      Hoger beroepsonderwijs  Onderwijsrichting onbekend
# 3756        5640  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3757        5641  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3758        5642  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3759        5643  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3760        5644  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3761        5645  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3762        5646  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3763        5647  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3764        5648  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3765        5649  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3766        5650  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3767        5651  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
#
#       Perioden  Enrollment  Freshmen
# 1872      2010           0         0
# 1873      2011           0         0
# 1874      2012           0         0
# 1875      2013           0         0
# 1876      2014           0         0
# 1877      2015           0         0
# 1878      2016           0         0
# 1879      2017           0         0
# 1880      2018           0         0
# 1881      2019           0         0
# 1882      2020           0         0
# 1883      2021           0         0
# 3756      2010         484       143
# 3757      2011         524       124
# 3758      2012         364        68
# 3759      2013         423       109
# 3760      2014         466       122
# 3761      2015         470        90
# 3762      2016         481        97
# 3763      2017         476        86
# 3764      2018         445        77
# 3765      2019         416        76
# 3766      2020         406       103
# 3767      2021         412        77

# %%
#I'll drop the stuff for Hoger beroepsonderwijs

# %%
onbekend = onbekend[onbekend['Onderwijssoort'] == "Wetenschappelijk onderwijs"]

# %%
onbekend = onbekend.reset_index()

# %%
onbekend
# Out:
#     index  Unnamed: 0              Onderwijssoort              Studierichting  \
# 0    3756        5640  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 1    3757        5641  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 2    3758        5642  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3    3759        5643  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 4    3760        5644  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 5    3761        5645  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 6    3762        5646  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 7    3763        5647  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 8    3764        5648  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 9    3765        5649  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 10   3766        5650  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 11   3767        5651  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
#
#     Perioden  Enrollment  Freshmen
# 0       2010         484       143
# 1       2011         524       124
# 2       2012         364        68
# 3       2013         423       109
# 4       2014         466       122
# 5       2015         470        90
# 6       2016         481        97
# 7       2017         476        86
# 8       2018         445        77
# 9       2019         416        76
# 10      2020         406       103
# 11      2021         412        77

# %%
totals = data[(data['Onderwijssoort'] == 'Wetenschappelijk onderwijs') & (data["Studierichting"] == "Totaal")]

# Then change the column name so that it does not conflict with the index when I concatenate:

totals = totals.rename(columns = {'Enrollment': 'Total'})

totals = totals.reset_index()

# %%
new = pd.concat([onbekend, totals['Total']], axis = 1)

# %%
new.head(60)
# Out:
#     index  Unnamed: 0              Onderwijssoort              Studierichting  \
# 0    3756        5640  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 1    3757        5641  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 2    3758        5642  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3    3759        5643  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 4    3760        5644  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 5    3761        5645  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 6    3762        5646  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 7    3763        5647  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 8    3764        5648  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 9    3765        5649  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 10   3766        5650  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 11   3767        5651  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
#
#     Perioden  Enrollment  Freshmen   Total
# 0       2010         484       143  242381
# 1       2011         524       124  245428
# 2       2012         364        68  241372
# 3       2013         423       109  250186
# 4       2014         466       122  255661
# 5       2015         470        90  261169
# 6       2016         481        97  268027
# 7       2017         476        86  280038
# 8       2018         445        77  294712
# 9       2019         416        76  306888
# 10      2020         406       103  331419
# 11      2021         412        77  344721

# %%
new['percentage'] = (new['Enrollment'] / new['Total'] * 100)

# %%
new
# Out:
#     index  Unnamed: 0              Onderwijssoort              Studierichting  \
# 0    3756        5640  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 1    3757        5641  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 2    3758        5642  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 3    3759        5643  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 4    3760        5644  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 5    3761        5645  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 6    3762        5646  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 7    3763        5647  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 8    3764        5648  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 9    3765        5649  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 10   3766        5650  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
# 11   3767        5651  Wetenschappelijk onderwijs  Onderwijsrichting onbekend
#
#     Perioden  Enrollment  Freshmen   Total  percentage
# 0       2010         484       143  242381    0.199686
# 1       2011         524       124  245428    0.213505
# 2       2012         364        68  241372    0.150805
# 3       2013         423       109  250186    0.169074
# 4       2014         466       122  255661    0.182273
# 5       2015         470        90  261169    0.179960
# 6       2016         481        97  268027    0.179460
# 7       2017         476        86  280038    0.169977
# 8       2018         445        77  294712    0.150995
# 9       2019         416        76  306888    0.135554
# 10      2020         406       103  331419    0.122504
# 11      2021         412        77  344721    0.119517

# %% [markdown]
# OK - this is all peanuts - between .1 and .2 % of the totals. And it seems like it might well be a data entry issue. So I'll ignore those 'Onderwijsrichting onbekend' things.

# %% [markdown]
# # End of detour, back to our main attraction

# %% [markdown]
# The next order of business is to generate separate dataframes for each of the ten major directions (01-10), so that I can put them all together in a pretty little plot, showing the year by year trends.

# %% [markdown]
# I will first separate the HBO (Hoger beroepsonderwijs - vocational training) from WO (Wetenschappelijk onderwijs - university)

# %%
level1
# Out:
#       Unnamed: 0              Onderwijssoort      Studierichting  Perioden  \
# 12          1896      Hoger beroepsonderwijs        01 Onderwijs      2010
# 13          1897      Hoger beroepsonderwijs        01 Onderwijs      2011
# 14          1898      Hoger beroepsonderwijs        01 Onderwijs      2012
# 15          1899      Hoger beroepsonderwijs        01 Onderwijs      2013
# 16          1900      Hoger beroepsonderwijs        01 Onderwijs      2014
# ...          ...                         ...                 ...       ...
# 3523        5407  Wetenschappelijk onderwijs  10 Dienstverlening      2017
# 3524        5408  Wetenschappelijk onderwijs  10 Dienstverlening      2018
# 3525        5409  Wetenschappelijk onderwijs  10 Dienstverlening      2019
# 3526        5410  Wetenschappelijk onderwijs  10 Dienstverlening      2020
# 3527        5411  Wetenschappelijk onderwijs  10 Dienstverlening      2021
#
#       Enrollment  Freshmen
# 12         77857     15372
# 13         75008     14107
# 14         70683     13108
# 15         72145     13724
# 16         72412     13490
# ...          ...       ...
# 3523        1394       286
# 3524        1585       348
# 3525        1767       423
# 3526        2260       536
# 3527        2511       496
#
# [240 rows x 6 columns]

# %%
level1_hbo = level1[level1['Onderwijssoort'] == 'Hoger beroepsonderwijs'].copy()

# %%
level1_wo = level1[level1['Onderwijssoort'] == 'Wetenschappelijk onderwijs'].copy()

# %% [markdown]
# I'm exporting both of these sets to be able to do some exploring in tableau

# %%
level1_hbo.to_csv("level1_hbo.csv", sep = ";")

# %%
level1_wo.to_csv("level1_wo.csv", sep = ";")

# %%
totals.to_csv("totals_wo.csv", sep = ";")

# %% [markdown]
# ## Post tableau considerations

# %% [markdown]
# From looking at the data, it looks like enrollments in pretty much all areas increased year by year, but some increased faster than others. I need some more precise metrics. The two metrics that I will want to retrieve next are:
# - Enrollments as % of total enrollments
# - Growth rate in % (compared to last year)

# %% [markdown]
# #### First I'll get the enrollment as % of total enrollment

# %%
# I'll make a dictionary of total new enrollments per year:
freshdict = dict(zip(totals.Perioden.tolist(), totals.Freshmen.tolist()))

# %%
percentages = []
for i in range(len(level1_wo)):
    year = level1_wo['Perioden'].iloc[i]
    freshmen = level1_wo['Freshmen'].iloc[i]
    percentages.append((freshmen/freshdict[year])*100)

# %%
level1_wo['percent'] = percentages

# %%
level1_wo.to_csv("level1_wo.csv", sep = ";")

# %%
# Same for HBO, except I need to re-calibrate the total values first:

# %%
totals_hbo = data[(data['Onderwijssoort'] == 'Hoger beroepsonderwijs') & (data["Studierichting"] == "Totaal")]

# %%
freshdict_hbo = dict(zip(totals_hbo.Perioden.tolist(), totals_hbo.Freshmen.tolist()))

# %%
percentages_hbo = []
for i in range(len(level1_hbo)):
    year = level1_hbo['Perioden'].iloc[i]
    freshmen = level1_hbo['Freshmen'].iloc[i]
    percentages_hbo.append((freshmen/freshdict_hbo[year])*100)

# %%
level1_hbo['percent'] = percentages_hbo

# %%
level1_hbo.to_csv("level1_hbo.csv", sep = ";")

# %%
level1 = pd.concat([level1_hbo, level1_wo], axis = 0)

# %%
level1 = level1.drop(columns = ["Unnamed: 0"])

# %% [markdown]
# ### Next I'll get the growth rate for every year.
#
# Since my dataset starts in 2010, I can't get a growth rate for that year. In this case, that actually saves me a lot of work - there's a pandas function/method that calculates each row as a percent increase from the previous row. If I won't be able to use the 2010 values anyway, I can just use this function, and then discard/transform the 2010 data.

# %%
level1['Growth Rate'] = round((level1['Freshmen'].pct_change()*100), 1)

# %%
for i in range(len(level1)):
    if level1['Perioden'].iloc[i] == 2010:
        level1['Growth Rate'].iloc[i] = 0
# Out:
# /var/folders/pv/w_93n1z92n56cjz9djzt80h40000gp/T/ipykernel_3750/330058404.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   level1['Growth Rate'].iloc[i] = 0

# %%
level1.head(60)
# Out:
#              Onderwijssoort                            Studierichting  \
# 12   Hoger beroepsonderwijs                              01 Onderwijs
# 13   Hoger beroepsonderwijs                              01 Onderwijs
# 14   Hoger beroepsonderwijs                              01 Onderwijs
# 15   Hoger beroepsonderwijs                              01 Onderwijs
# 16   Hoger beroepsonderwijs                              01 Onderwijs
# 17   Hoger beroepsonderwijs                              01 Onderwijs
# 18   Hoger beroepsonderwijs                              01 Onderwijs
# 19   Hoger beroepsonderwijs                              01 Onderwijs
# 20   Hoger beroepsonderwijs                              01 Onderwijs
# 21   Hoger beroepsonderwijs                              01 Onderwijs
# 22   Hoger beroepsonderwijs                              01 Onderwijs
# 23   Hoger beroepsonderwijs                              01 Onderwijs
# 96   Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 97   Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 98   Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 99   Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 100  Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 101  Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 102  Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 103  Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 104  Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 105  Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 106  Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 107  Hoger beroepsonderwijs  02 Vormgeving, kunst, talen en gesch...
# 324  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 325  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 326  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 327  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 328  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 329  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 330  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 331  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 332  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 333  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 334  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 335  Hoger beroepsonderwijs  03 Journalistiek, gedrag en maatschappij
# 480  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 481  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 482  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 483  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 484  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 485  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 486  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 487  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 488  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 489  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 490  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 491  Hoger beroepsonderwijs    04 Recht, administratie, handel en za…
# 648  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 649  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 650  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 651  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 652  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 653  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 654  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 655  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 656  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 657  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 658  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
# 659  Hoger beroepsonderwijs          05 Wiskunde, natuurwetenschappen
#
#      Perioden  Enrollment  Freshmen    percent  Growth Rate
# 12       2010       77857     15372  15.356030          0.0
# 13       2011       75008     14107  14.246761         -8.2
# 14       2012       70683     13108  13.512566         -7.1
# 15       2013       72145     13724  13.347987          4.7
# 16       2014       72412     13490  13.694736         -1.7
# 17       2015       69728     10962  12.148818        -18.7
# 18       2016       68726     11287  11.861699          3.0
# 19       2017       67327     11607  11.553507          2.8
# 20       2018       66265     12080  11.771929          4.1
# 21       2019       66727     12655  12.060766          4.8
# 22       2020       71322     15113  13.070816         19.4
# 23       2021       71863     12993  12.508303        -14.0
# 96       2010       29037      6913   6.905818          0.0
# 97       2011       29575      6984   7.053192          1.0
# 98       2012       29634      6840   7.051110         -2.1
# 99       2013       30162      7015   6.822802          2.6
# 100      2014       30567      6843   6.946855         -2.5
# 101      2015       30097      6315   6.998703         -7.7
# 102      2016       30220      6659   6.998056          5.4
# 103      2017       30834      7298   7.264366          9.6
# 104      2018       33479      9135   8.902034         25.2
# 105      2019       35459      9291   8.854728          1.7
# 106      2020       38697     10011   8.658237          7.7
# 107      2021       40572      9334   8.985800         -6.8
# 324      2010       28043      6737   6.730001          0.0
# 325      2011       28733      6767   6.834042          0.4
# 326      2012       28578      6281   6.474857         -7.2
# 327      2013       29247      6258   6.086542         -0.4
# 328      2014       28701      5622   5.707325        -10.2
# 329      2015       27430      4918   5.450455        -12.5
# 330      2016       26633      5351   5.623456          8.8
# 331      2017       26291      5625   5.599076          5.1
# 332      2018       25059      4974   4.847150        -11.6
# 333      2019       25467      5653   5.387555         13.7
# 334      2020       27053      6528   5.645887         15.5
# 335      2021       27014      5857   5.638508        -10.3
# 480      2010      109949     27316  27.287621          0.0
# 481      2011      114687     28070  28.348095          2.8
# 482      2012      114528     27415  28.261138         -2.3
# 483      2013      119366     28265  27.490590          3.1
# 484      2014      120884     27054  27.464596         -4.3
# 485      2015      119189     24764  27.445113         -8.5
# 486      2016      119864     26135  27.465714          5.5
# 487      2017      121606     27663  27.535511          5.8
# 488      2018      122365     28270  27.549042          2.2
# 489      2019      123802     28327  26.996864          0.2
# 490      2020      129600     30866  26.695150          9.0
# 491      2021      128546     27823  26.785078         -9.9
# 648      2010        3721      1037   1.035923          0.0
# 649      2011        3951      1047   1.057373          1.0
# 650      2012        4250      1132   1.166938          8.1
# 651      2013        5023      1446   1.406382         27.7
# 652      2014        5538      1494   1.516674          3.3
# 653      2015        6498      1725   1.911760         15.5
# 654      2016        7025      1832   1.925280          6.2
# 655      2017        7220      1756   1.747907         -4.1
# 656      2018        7432      1741   1.696600         -0.9
# 657      2019        7506      1701   1.621127         -2.3
# 658      2020        7944      1920   1.660555         12.9
# 659      2021        7867      1649   1.587485        -14.1

# %%
level1.to_csv("level1.csv", sep = ";")

# %% [markdown]
# # Next, I'll look at data by gender

# %%
level1mf = pd.read_csv("data_gendered.csv", sep = ";")

# %%
level1mf
# Out:
#       Unnamed: 0 Geslacht              Onderwijssoort  \
# 0          64056   Mannen      Hoger beroepsonderwijs
# 1          64057   Mannen      Hoger beroepsonderwijs
# 2          64058   Mannen      Hoger beroepsonderwijs
# 3          64059   Mannen      Hoger beroepsonderwijs
# 4          64060   Mannen      Hoger beroepsonderwijs
# ...          ...      ...                         ...
# 7531      129991  Vrouwen  Wetenschappelijk onderwijs
# 7532      129992  Vrouwen  Wetenschappelijk onderwijs
# 7533      129993  Vrouwen  Wetenschappelijk onderwijs
# 7534      129994  Vrouwen  Wetenschappelijk onderwijs
# 7535      129995  Vrouwen  Wetenschappelijk onderwijs
#
#                   Studierichting  Perioden  Enrollment  Freshmen
# 0                         Totaal      2010      198810     47089
# 1                         Totaal      2011      203973     47227
# 2                         Totaal      2012      203585     46243
# 3                         Totaal      2013      213624     48310
# 4                         Totaal      2014      217203     46825
# ...                          ...       ...         ...       ...
# 7531  Onderwijsrichting onbekend      2017         226        47
# 7532  Onderwijsrichting onbekend      2018         201        47
# 7533  Onderwijsrichting onbekend      2019         196        39
# 7534  Onderwijsrichting onbekend      2020         210        59
# 7535  Onderwijsrichting onbekend      2021         230        48
#
# [7536 rows x 7 columns]

# %%
# Get the total counts per year
totalsmf_hbo = data[(data['Studierichting'] == "Totaal") & (data['Onderwijssoort'] == 'Hoger beroepsonderwijs')]
totalsmf_wo = data[(data['Studierichting'] == "Totaal") & (data['Onderwijssoort'] == 'Wetenschappelijk onderwijs')]

# %%
totalsmf_hbo
# Out:
#     Unnamed: 0          Onderwijssoort Studierichting  Perioden  Enrollment  \
# 0         1884  Hoger beroepsonderwijs         Totaal      2010      416638
# 1         1885  Hoger beroepsonderwijs         Totaal      2011      423945
# 2         1886  Hoger beroepsonderwijs         Totaal      2012      421693
# 3         1887  Hoger beroepsonderwijs         Totaal      2013      440293
# 4         1888  Hoger beroepsonderwijs         Totaal      2014      446434
# 5         1889  Hoger beroepsonderwijs         Totaal      2015      442594
# 6         1890  Hoger beroepsonderwijs         Totaal      2016      446645
# 7         1891  Hoger beroepsonderwijs         Totaal      2017      452690
# 8         1892  Hoger beroepsonderwijs         Totaal      2018      455670
# 9         1893  Hoger beroepsonderwijs         Totaal      2019      463330
# 10        1894  Hoger beroepsonderwijs         Totaal      2020      489262
# 11        1895  Hoger beroepsonderwijs         Totaal      2021      491499
#
#     Freshmen
# 0     100104
# 1      99019
# 2      97006
# 3     102817
# 4      98505
# 5      90231
# 6      95155
# 7     100463
# 8     102617
# 9     104927
# 10    115624
# 11    103875

# %%
level1mf = level1mf[level1mf['Studierichting'].str.contains('^[0-9][0-9] ', regex=True)]
# This filters out the cases where field of study is unknown, or is an aggregation of the total, 
# As well as narrowing the field to only the 'outer layer' of specificity (10 categories)

# %%
# Next, again generate the percentages. I'll first split WO and HBO again

# %%
hbomf = level1mf[level1mf['Onderwijssoort'] == "Hoger beroepsonderwijs"]
womf = level1mf[level1mf['Onderwijssoort'] == "Wetenschappelijk onderwijs"]

# %%
# Then I'll get the totals for both 

hbomfdict = dict(zip(totalsmf_hbo.Perioden.tolist(), totalsmf_hbo.Freshmen.tolist()))
womfdict = dict(zip(totalsmf_wo.Perioden.tolist(), totalsmf_wo.Freshmen.tolist()))

# %%
hbopercentages = []
for i in range(len(hbomf)):
    year = hbomf['Perioden'].iloc[i]
    freshmen = hbomf['Freshmen'].iloc[i]
    hbopercentages.append((freshmen/hbomfdict[year])*100)

# %%
hbomf['Percent'] = hbopercentages
# Out:
# /var/folders/pv/w_93n1z92n56cjz9djzt80h40000gp/T/ipykernel_3750/2688666074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hbomf['Percent'] = hbopercentages

# %%
wopercentages = []
for i in range(len(womf)):
    year = womf['Perioden'].iloc[i]
    freshmen = womf['Freshmen'].iloc[i]
    wopercentages.append((freshmen/womfdict[year])*100)

# %%
womf['Percent'] = wopercentages
# Out:
# /var/folders/pv/w_93n1z92n56cjz9djzt80h40000gp/T/ipykernel_3750/1467629444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   womf['Percent'] = wopercentages

# %%
womf
# Out:
#       Unnamed: 0 Geslacht              Onderwijssoort      Studierichting  \
# 1896       65952   Mannen  Wetenschappelijk onderwijs        01 Onderwijs
# 1897       65953   Mannen  Wetenschappelijk onderwijs        01 Onderwijs
# 1898       65954   Mannen  Wetenschappelijk onderwijs        01 Onderwijs
# 1899       65955   Mannen  Wetenschappelijk onderwijs        01 Onderwijs
# 1900       65956   Mannen  Wetenschappelijk onderwijs        01 Onderwijs
# ...          ...      ...                         ...                 ...
# 7291      129751  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
# 7292      129752  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
# 7293      129753  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
# 7294      129754  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
# 7295      129755  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
#
#       Perioden  Enrollment  Freshmen   Percent
# 1896      2010        1329       167  0.318380
# 1897      2011        1423       172  0.325603
# 1898      2012        1351       162  0.311449
# 1899      2013        1466       147  0.265147
# 1900      2014        1375       153  0.275919
# ...        ...         ...       ...       ...
# 7291      2017         652       159  0.236695
# 7292      2018         747       188  0.261871
# 7293      2019         809       213  0.291677
# 7294      2020        1035       281  0.345065
# 7295      2021        1133       247  0.304498
#
# [240 rows x 8 columns]

# %% [markdown]
# Then concatenate the dataframe again

# %%
level1mf = pd.concat([hbomf, womf], axis = 0)

# %%
level1mf
# Out:
#       Unnamed: 0 Geslacht              Onderwijssoort      Studierichting  \
# 12         64068   Mannen      Hoger beroepsonderwijs        01 Onderwijs
# 13         64069   Mannen      Hoger beroepsonderwijs        01 Onderwijs
# 14         64070   Mannen      Hoger beroepsonderwijs        01 Onderwijs
# 15         64071   Mannen      Hoger beroepsonderwijs        01 Onderwijs
# 16         64072   Mannen      Hoger beroepsonderwijs        01 Onderwijs
# ...          ...      ...                         ...                 ...
# 7291      129751  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
# 7292      129752  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
# 7293      129753  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
# 7294      129754  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
# 7295      129755  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening
#
#       Perioden  Enrollment  Freshmen   Percent
# 12        2010       22228      4244  4.239591
# 13        2011       21837      3974  4.013371
# 14        2012       20927      3720  3.834814
# 15        2013       22195      4011  3.901106
# 16        2014       22451      3824  3.882036
# ...        ...         ...       ...       ...
# 7291      2017         652       159  0.236695
# 7292      2018         747       188  0.261871
# 7293      2019         809       213  0.291677
# 7294      2020        1035       281  0.345065
# 7295      2021        1133       247  0.304498
#
# [480 rows x 8 columns]

# %% [markdown]
# ### And again generate the growth rate in percentages

# %%
level1mf['Growth Rate'] = round((level1mf['Freshmen'].pct_change()*100), 1)

# %%
for i in range(len(level1mf)):
    if level1mf['Perioden'].iloc[i] == 2010:
        level1mf['Growth Rate'].iloc[i] = 0
# Out:
# /var/folders/pv/w_93n1z92n56cjz9djzt80h40000gp/T/ipykernel_3750/4214950272.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   level1mf['Growth Rate'].iloc[i] = 0

# %%
level1mf = level1mf.drop(columns = "Unnamed: 0").reset_index().copy()

# %%
level1mf
# Out:
#      index Geslacht              Onderwijssoort      Studierichting  Perioden  \
# 0       12   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2010
# 1       13   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2011
# 2       14   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2012
# 3       15   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2013
# 4       16   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2014
# ..     ...      ...                         ...                 ...       ...
# 475   7291  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2017
# 476   7292  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2018
# 477   7293  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2019
# 478   7294  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2020
# 479   7295  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2021
#
#      Enrollment  Freshmen   Percent  Growth Rate
# 0         22228      4244  4.239591          0.0
# 1         21837      3974  4.013371         -6.4
# 2         20927      3720  3.834814         -6.4
# 3         22195      4011  3.901106          7.8
# 4         22451      3824  3.882036         -4.7
# ..          ...       ...       ...          ...
# 475         652       159  0.236695         29.3
# 476         747       188  0.261871         18.2
# 477         809       213  0.291677         13.3
# 478        1035       281  0.345065         31.9
# 479        1133       247  0.304498        -12.1
#
# [480 rows x 9 columns]

# %% [markdown]
# ### And then export this to .csv, to work with in Tableau

# %%
level1mf.to_csv("level1mf.csv", sep = ";")

# %% [markdown]
# # Next, I want to get the male/female ratios for each cohort of freshmen

# %%
m = level1mf[level1mf['Geslacht'] == "Mannen"].copy()
f = level1mf[level1mf['Geslacht'] == "Vrouwen"].copy()

# %%
m = m.reset_index()
f = f.reset_index()

# %%
ratio = f['Freshmen'] / m['Freshmen']

# %%
ratio
# Out:
# 0      2.622055
# 1      2.549824
# 2      2.523656
# 3      2.421591
# 4      2.527720
#          ...
# 235    1.251969
# 236    1.175000
# 237    1.014286
# 238    1.101961
# 239    0.991968
# Name: Freshmen, Length: 240, dtype: float64

# %%
ratio.describe()
# Out:
# count    240.000000
# mean       1.758318
# std        2.148271
# min        0.045381
# 25%        0.697495
# 50%        1.024259
# 75%        2.167986
# max       11.625850
# Name: Freshmen, dtype: float64

# %% [markdown]
# The number in 'ratio' is the number of female students for every male student

# %% [markdown]
# ### I think the best way to deal with this info is to concatenate it with itself (giving the same list twice), and then add the resulting series as a column to my level1mf.csv. This is bad form for a database (lots of redundancy), but makes it much easier to work with in Tableau.

# %% [markdown]
# I found out the hard way that the straightforward concatenation mixes things up. The order of level1mf is as follows:
# - 120x M, HBO
# - 120x F, HBO
# - 120x M, Uni
# - 120x F, Uni
#
# While the order of my 'ratio' is 120x HBO, 120x Uni.
#
# So what I really need to do is cut the 'ratio' list in half, and concatenate the first half with itself and the second half with itself (HBO with HBO, Uni with Uni), and concatenate both together. THAT will give me the right order for the data.

# %%
ratiolist = ratio.tolist()

# %%
len(ratiolist)
# Out:
# 240

# %%
ratiohbo = ratiolist[0:120]

# %%
ratiowo = ratiolist[120:]

# %%
ratiohbo2 = ratiohbo + ratiohbo

# %%
len(ratiohbo2)
# Out:
# 240

# %%
ratiowo2 = ratiowo + ratiowo

# %%
finalratios = ratiohbo2 + ratiowo2

# %% [markdown]
# len(finalratios)

# %%
level1mf['Ratio'] = finalratios

# %%
level1mf
# Out:
#      index Geslacht              Onderwijssoort      Studierichting  Perioden  \
# 0       12   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2010
# 1       13   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2011
# 2       14   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2012
# 3       15   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2013
# 4       16   Mannen      Hoger beroepsonderwijs        01 Onderwijs      2014
# ..     ...      ...                         ...                 ...       ...
# 475   7291  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2017
# 476   7292  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2018
# 477   7293  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2019
# 478   7294  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2020
# 479   7295  Vrouwen  Wetenschappelijk onderwijs  10 Dienstverlening      2021
#
#      Enrollment  Freshmen   Percent  Growth Rate     Ratio
# 0         22228      4244  4.239591          0.0  2.622055
# 1         21837      3974  4.013371         -6.4  2.549824
# 2         20927      3720  3.834814         -6.4  2.523656
# 3         22195      4011  3.901106          7.8  2.421591
# 4         22451      3824  3.882036         -4.7  2.527720
# ..          ...       ...       ...          ...       ...
# 475         652       159  0.236695         29.3  1.251969
# 476         747       188  0.261871         18.2  1.175000
# 477         809       213  0.291677         13.3  1.014286
# 478        1035       281  0.345065         31.9  1.101961
# 479        1133       247  0.304498        -12.1  0.991968
#
# [480 rows x 10 columns]

# %% [markdown]
# This is the point at which I *actually* did the work in SQL (I made the connection way way above, but didn't start looking at it until this point.) That gives me another round of cleaning.
#
# I'll start a new notebook for that.

# %% [markdown]
# # Towards the hypothesis test

# %%
level1_df = level1[level1["Onderwijssoort"] == "Wetenschappelijk onderwijs"]

# %% [markdown]
# Then extract two sets of growth rates - those for 2015 (the 'sample') and those for the other years.

# %%
sample2015 = level1_df["Growth Rate"][level1_df["Perioden"] == 2015]

# %%
sample2015
# Out:
# 1901    -3.3
# 1985    -5.4
# 2213     1.4
# 2369     0.2
# 2537     4.8
# 2777    12.3
# 2885    12.1
# 3149     0.3
# 3305     0.6
# 3521    -1.1
# Name: Growth Rate, dtype: float64

# %%
pop = level1_df["Growth Rate"][level1_df["Perioden"] != 2010] 
# 2010 only has values of 0, because the growth rate is compared to the previous year, so the first year has no values.

# %%
# Calculate both means:

# %%
np.mean(sample2015)
# Out:
# 2.19

# %%
np.mean(pop)
# Out:
# 5.314545454545455

# %% [markdown]
# (Using pseudocode rather than any type of scientifico-mathematical notation. Still learning here!)
#
# My H0: mean(sample) == mean(pop)
#
# H1: mean(sample) != mean(pop)

# %%
from scipy.stats import ttest_1samp

stat, pval = ttest_1samp(pop, np.mean(sample2015))

# %%
stat
# Out:
# 3.4613406260856414

# %%
pval
# Out:
# 0.0007686462141271805

# %% [markdown]
# The p value is low, so the null hypothesis must go.
#
# But... what does it *mean*?

# %% [markdown]
# I'm going to try the same for every year, just to check if this is really special for 2015

# %%
def getpval(list_of_years):
    for year in list_of_years:
        sample = level1_df["Growth Rate"][level1_df["Perioden"] == year]
        stat, pval = ttest_1samp(pop, np.mean(sample))
        print("Year:", year)
        print("pval: ", pval)
        print("stat: ", stat)
    return

# %%
yearlist = [year for year in range(2011,2022)]
yearlist
# Out:
# [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
getpval(yearlist)
# Out:
# Year: 2011
# pval:  7.396386913884741e-10
# stat:  6.751477322455088
# Year: 2012
# pval:  1.9384852734358645e-09
# stat:  6.552075098432698
# Year: 2013
# pval:  0.005352866300513634
# stat:  -2.84198523328882
# Year: 2014
# pval:  0.013591539580005908
# stat:  2.508641111311997
# Year: 2015
# pval:  0.0007686462141271805
# stat:  3.4613406260856414
# Year: 2016
# pval:  0.011329729648860703
# stat:  -2.5761156012589663
# Year: 2017
# pval:  1.5055611979750433e-17
# stat:  -10.19771171944812
# Year: 2018
# pval:  0.19186164021095778
# stat:  -1.313234849117158
# Year: 2019
# pval:  0.7357281109927192
# stat:  -0.3383795316743602
# Year: 2020
# pval:  7.227078437894019e-14
# stat:  -8.58033812459984
# Year: 2021
# pval:  1.742641652120906e-09
# stat:  6.574230901101852
